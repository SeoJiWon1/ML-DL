# %% [markdown]
# <a href="https://colab.research.google.com/github/SeoJiWon1/ML-DL/blob/main/Open_CV_%EC%9D%B4%EB%AF%B8%EC%A7%80_%EC%97%B0%EC%82%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Open CV 이미지 연산

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d147d2a9-4113-4088-9366-18b2cc668705" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d147d2a9-4113-4088-9366-18b2cc668705">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## OpenCV를 활용한 이미지 크기 및 픽셀 정보 확인

# %%
import cv2
image = cv2.imread('ming.jpg')

# 픽셀 수 및 이미지 크기 확인
print(image.shape)
print(image.size)
# Out:
# (973, 1125, 3)
# 3283875

# %%
# 이미지 Numpy 객체의 특정 픽셀을 가리킨다.
px = image[100, 100]

# B, G, R 순서로 출력
# (단, Gray Scale인 경우에는 B, G ,R 로 구분되지 않는다.)
print(px)
# Out:
# [90 94 99]

# %%
# R 값만 출력하기
print(px[2])
# Out:
# 99

# %% [markdown]
# ## OpenCV를 활용한 특정 범위 픽셀 변경

# %%
import cv2
import matplotlib.pyplot as plt
import time 

image = cv2.imread('ming.jpg')

start_time = time.time()
for i in range(0, 100):
    for j in range(0, 100):
        image[i,j] = [255, 255, 255]
print('---%s seconds ---' % (time.time() - start_time))

start_time = time.time()
image[0:100, 0:100] = [0, 0, 0]
print("--- %s seconds ---" % (time.time() - start_time))

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---0.012520074844360352 seconds ---
# --- 0.00029850006103515625 seconds ---

# %% [markdown]
# ## OpenCV를 활용한 픽셀별 색상 다루기

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('ming.jpg')
image[:, : , 2] = 0

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
